# %%
import pandas as pd

# %%
"""
La idea es usar los datos de los partidos jugados de los últimos 20 años para crear modelo que pueda predecir resultados
de los partidos. También, se puede hacer un head 2 head entre los jugadores. Por último, un modelo que indica cómo crecieron
los jugadores a lo largo de los años.
"""
# Out:
# '\nLa idea es usar los datos de los partidos jugados de los últimos 20 años para crear modelo que pueda predecir resultados\nde los partidos. También, se puede hacer un head 2 head entre los jugadores. Por último, un modelo que indica cómo crecieron\nlos jugadores a lo largo de los años.\n'

# %%
dt = pd.read_csv('atp_matches_till_2022.csv')

# %%
dt.shape
# Out:
# (188161, 49)

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', None)

# %%
dt.head(1000)
# Out:
#     tourney_id         tourney_name surface  draw_size tourney_level  \
# 0    1968-2029               Dublin   Grass         32             A
# 1    1968-2029               Dublin   Grass         32             A
# 2    1968-2029               Dublin   Grass         32             A
# 3    1968-2029               Dublin   Grass         32             A
# 4    1968-2029               Dublin   Grass         32             A
# 5    1968-2029               Dublin   Grass         32             A
# 6    1968-2029               Dublin   Grass         32             A
# 7    1968-2029               Dublin   Grass         32             A
# 8    1968-2029               Dublin   Grass         32             A
# 9    1968-2029               Dublin   Grass         32             A
# 10   1968-2029               Dublin   Grass         32             A
# 11   1968-2029               Dublin   Grass         32             A
# 12   1968-2029               Dublin   Grass         32             A
# ...

# %%
"""
w = winner/ganador, l = loser/perdedor
Columnas de interés: tourney_name = nombre del torneo, 
                    surface = superficie del partido, 
                    winner_name = nombre del ganador, 
                    lose_name = nombre del perdedor, 
                    winner_hand, 
                    loser_hand, 
                    score = resultado, 
                    best_of = indica la cantidad de sets que se juega el partido 3 o 5, 
                    minutes = minutos del partido, 
                    round = ronda(final, semis, cuartos, etc),
                    w_ace = cantidad de aces, 
                    l_ace = cantidad de aces, 
                    w_df = doble faltas, 
                    l_df = doble faltas, 
                    w_svpt = porcentaje de aciertos del saque, 
                    l_svpt = porcentaje de aciertos del saque, 
                    w_1stWon = puntos ganados con el primer saque, 
                    l_1stWon = puntos ganados con el primer saque, 
                    w_1stIn = puntos acertados con el primer saque, 
                    l_1stIn = puntos acertados con el primer saque, 
                    w_bpSaved = break points salvados, 
                    l_bpSaved = break points salvados,
                    w_bpFaced = break points en contra, 
                    l_bpFaced = break points en contra.
"""
# Out:
# '\nColumnas de interés: tourney_name, surface, winner_name, lose_name, winner_hand, loser_hand, score, best_of, minutes, round,\n                    w_ace, l_ace, w_df, l_df, w_svpt, l_svpt, w_1stWon, l_1stWon, w_1stIn, l_1stIn, w_bpSaved, l_bpSaved,\n                    w_bpFaced, l_bpFaced, etc.\n'

# %%
dt.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'loser_id', 'loser_seed', 'loser_entry', 'loser_name', 'loser_hand',
#        'loser_ht', 'loser_ioc', 'loser_age', 'score', 'best_of', 'round',
#        'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon', 'w_2ndWon',
#        'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df', 'l_svpt',
#        'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved', 'l_bpFaced',
#        'winner_rank', 'winner_rank_points', 'loser_rank', 'loser_rank_points'],
#       dtype='object')
